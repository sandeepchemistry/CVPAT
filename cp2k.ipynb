# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepchemistry/CVPAT/blob/master/cp2k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import clear_output

# %%
####### ssmp version #######
'''
from IPython.display import clear_output

# install cp2k
# !mkdir cp2k_bin
# !wget -q https://github.com/cp2k/cp2k/releases/download/v2024.1/cp2k-2024.1-Linux-gnu-x86_64.ssmp -O /content/cp2k_bin/cp2k-2024.1-Linux-gnu-x86_64.ssmp
# !chmod +x /content/cp2k_bin/cp2k-2024.1-Linux-gnu-x86_64.ssmp
# !ln -s /content/cp2k_bin/cp2k-2024.1-Linux-gnu-x86_64.ssmp /content/cp2k_bin/cp2k

# enviroment variable setting
import os
os.environ["PATH"] += ":/content/cp2k_bin"
'''
# Out:
# mkdir: cannot create directory ‘cp2k_bin’: File exists

# %%
####### sopt version #######

from IPython.display import clear_output

# install cp2k
# !mkdir cp2k_bin
# !wget -q https://github.com/cp2k/cp2k/releases/download/v7.1.0/cp2k-7.1-Linux-x86_64.sopt -O /content/cp2k_bin/cp2k-7.1-Linux-x86_64.sopt
# !chmod +x /content/cp2k_bin/cp2k-7.1-Linux-x86_64.sopt
# !ln -s /content/cp2k_bin/cp2k-7.1-Linux-x86_64.sopt /content/cp2k_bin/cp2k

# enviroment variable setting
import os
os.environ["PATH"] += ":/content/cp2k_bin"

# %%
# !cp2k --version
# Out:
#  CP2K version 7.1
#  Source code revision git:e635599
#  cp2kflags: libint fftw3 libxc xsmm spglib
#  compiler: GCC version 7.4.1 20190905 [gcc-7-branch revision 275407]
#  compiler options:
#    -cpp -I /home/krack/gnu/7.4.0/fftw/3.3/include -I /home/krack/gnu/7.
#    4.0/libint/2.6.0-lmax-6/include -I /home/krack/gnu/7.4.0/libxc/4.3.4
#    /include -I /home/krack/gnu/7.4.0/libxsmm/1.14/include -I /home/krac
#    k/github/mkrack/cp2k/src/start/ -I /home/krack/github/mkrack/cp2k/ob
#    j/Linux-x86-64-gfortran/sopt/exts/dbcsr -D __FFTW3 -D __LIBINT -D __
#    LIBXC -D __LIBXSMM -D __SPGLIB -D __COMPILE_ARCH="Linux-x86-64-gfort
#    ran" -D __COMPILE_DATE="Mon Dec 23 19:20:03 CET 2019" -D __COMPILE_H
#    OST="pc9404" -D __COMPILE_REVISION="git:e635599" -D __DATA_DIR="/hom
#    e/krack/github/mkrack/cp2k/data" -D __SHORT_FILE__="start/cp2k.F" --
#    param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cach
# ...

# %%
# static_calculation
# %cd /content
# !wget -q https://www.cp2k.org/_media/static_calculation.tgz -O static_calculation.tgz
# !tar xf /content/static_calculation.tgz
# !rm /content/static_calculation.tgz
clear_output()

# run calculation
# %cd /content/static_calculation/sample_output_with_smearing
# !cp2k -i Si_bulk8.inp
# Out:
# /content/static_calculation/sample_output_with_smearing
#  DBCSR| CPU Multiplication driver                                           XSMM
#  DBCSR| Multrec recursion limit                                              512
#  DBCSR| Multiplication stack size                                           1000
#  DBCSR| Maximum elements for images                                    UNLIMITED
#  DBCSR| Multiplicative factor virtual images                                   1
#  DBCSR| Use multiplication densification                                       T
#  DBCSR| Multiplication size stacks                                             3
#
#
#   **** **** ******  **  PROGRAM STARTED AT               2024-05-21 17:50:35.733
#  ***** ** ***  *** **   PROGRAM STARTED ON                          1cd7083e3b48
#  **    ****   ******    PROGRAM STARTED BY                             <unknown>
#  ***** **    ** ** **   PROGRAM PROCESS ID                                 15231
# ...

# %%
# geo opt
# %cd /content
# !wget https://www.cp2k.org/_media/geometry_optimisation.tgz -O geoopt.tgz
# !tar xf /content/geoopt.tgz
# !rm /content/geoopt.tgz
clear_output()

# run calculation
# %cd /content/geometry_optimisation/sample_output
# !cp2k -i H2O.inp
# Out:
# /content/geometry_optimisation/sample_output
#  DBCSR| CPU Multiplication driver                                           XSMM
#  DBCSR| Multrec recursion limit                                              512
#  DBCSR| Multiplication stack size                                           1000
#  DBCSR| Maximum elements for images                                    UNLIMITED
#  DBCSR| Multiplicative factor virtual images                                   1
#  DBCSR| Use multiplication densification                                       T
#  DBCSR| Multiplication size stacks                                             3
#
#
#   **** **** ******  **  PROGRAM STARTED AT               2024-05-21 17:42:43.449
#  ***** ** ***  *** **   PROGRAM STARTED ON                          1cd7083e3b48
#  **    ****   ******    PROGRAM STARTED BY                             <unknown>
#  ***** **    ** ** **   PROGRAM PROCESS ID                                 13353
# ...
